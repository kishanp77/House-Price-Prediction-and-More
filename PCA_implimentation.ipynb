# %% [markdown]
# <a href="https://colab.research.google.com/github/kishanp77/kishanp77/blob/main/PCA_implimentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data
data = np.array([[2.5, 2.4],
                 [0.5, 0.7],
                 [2.2, 2.9],
                 [1.9, 2.2],
                 [3.1, 3.0],
                 [2.3, 2.7],
                 [2.0, 1.6],
                 [1.0, 1.1],
                 [1.5, 1.6],
                 [1.1, 0.9]])

# Calculate the mean of each variable
mean_X = np.mean(data[:, 0])
mean_Y = np.mean(data[:, 1])

# Center the data
centered_data = data - np.array([mean_X, mean_Y])

# Calculate the covariance matrix
cov_matrix = np.cov(centered_data.T)

# Calculate eigenvectors and eigenvalues
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# Print the covariance matrix
print("Covariance Matrix:")
print(cov_matrix)

# Print eigenvectors and eigenvalues
print("\nEigenvectors:")
print(eigenvectors)
print("\nEigenvalues:")
print(eigenvalues)

# Visualize the data and eigenvectors
plt.scatter(data[:, 0], data[:, 1])
plt.quiver(mean_X, mean_Y, eigenvectors[0, 0], eigenvectors[1, 0], color='r', scale=3)
plt.quiver(mean_X, mean_Y, eigenvectors[0, 1], eigenvectors[1, 1], color='b', scale=3)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Data and Eigenvectors')
plt.grid(True)
plt.show()
# Out:
# Covariance Matrix:
# [[0.61655556 0.61544444]
#  [0.61544444 0.71655556]]
#
# Eigenvectors:
# [[-0.73517866 -0.6778734 ]
#  [ 0.6778734  -0.73517866]]
#
# Eigenvalues:
# [0.0490834  1.28402771]
